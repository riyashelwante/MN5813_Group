# %% [markdown]
# # MN5813: 120 years of Olympic history: athletes and results

# %% [markdown]
# **Introduction:**
# The Olympics have always been a fascinating lens through which we can explore global sports, culture, and history. This report dives into the data behind the games, uncovering patterns and insights about participation, medal achievements, and gender representation. Along the way, we tackled challenges like missing information, unusual data values, and the impact of historical events on medal counts. By carefully cleaning and analysing the dataset, we were able to paint a clearer picture of how the Olympics have evolved over time and what they reveal about the world of sports.
#
# **Aim:**
# To uncover meaningful insights from Olympic data by analysing trends, medal distributions, and gender representation while addressing inconsistencies and historical nuances.
#
# **Objectives:**
#
# 1. Clean and Prepare the Data: Handle missing values, inconsistent entries, and unusual records like negative ages to ensure the dataset is ready for analysis.
#
# 2. Understand Historical Context: Acknowledge the impact of geopolitical changes, such as the dissolution of the Soviet Union, on medal counts and representation.
#
# 3. Highlight Gender Representation: Compare male and female participation in both the Summer and Winter Olympics to identify trends over time.
#
# 4. Track Participation Trends: Explore how the number of participating countries has grown over the years for each Olympic season.
#
# 5. Analyse Medal Performances:  Identify the top-performing countries and sports for both seasons to showcase global dominance and competitiveness.
#
# 6. Create Engaging Visuals:  Use charts and graphs to make the findings easy to understand and visually appealing.

# %% [markdown]
# **Link to GitHub:** \
# https://github.com/riyashelwante/MN5813_Group

# %%
import pandas as pd

#read athlete_events.csv file
df = pd.read_csv('athlete_events.csv')

#print first 10 records
df.head(10)
# Out:
#    ID                      Name Sex   Age  Height  Weight            Team  \
# 0   1                 A Dijiang   M  24.0   180.0    80.0           China
# 1   2                  A Lamusi   M  23.0   170.0    60.0           China
# 2   3       Gunnar Nielsen Aaby   M  24.0     NaN     NaN         Denmark
# 3   4      Edgar Lindenau Aabye   M  34.0     NaN     NaN  Denmark/Sweden
# 4   5  Christine Jacoba Aaftink   F  21.0   185.0    82.0     Netherlands
# 5   5  Christine Jacoba Aaftink   F  21.0   185.0    82.0     Netherlands
# 6   5  Christine Jacoba Aaftink   F  25.0   185.0    82.0     Netherlands
# 7   5  Christine Jacoba Aaftink   F  25.0   185.0    82.0     Netherlands
# 8   5  Christine Jacoba Aaftink   F  27.0   185.0    82.0     Netherlands
# 9   5  Christine Jacoba Aaftink   F  27.0   185.0    82.0     Netherlands
#
#    NOC        Games  Year  Season         City          Sport  \
# 0  CHN  1992 Summer  1992  Summer    Barcelona     Basketball
# 1  CHN  2012 Summer  2012  Summer       London           Judo
# 2  DEN  1920 Summer  1920  Summer    Antwerpen       Football
# 3  DEN  1900 Summer  1900  Summer        Paris     Tug-Of-War
# 4  NED  1988 Winter  1988  Winter      Calgary  Speed Skating
# 5  NED  1988 Winter  1988  Winter      Calgary  Speed Skating
# 6  NED  1992 Winter  1992  Winter  Albertville  Speed Skating
# 7  NED  1992 Winter  1992  Winter  Albertville  Speed Skating
# 8  NED  1994 Winter  1994  Winter  Lillehammer  Speed Skating
# 9  NED  1994 Winter  1994  Winter  Lillehammer  Speed Skating
#
#                                 Event Medal
# 0         Basketball Men's Basketball   NaN
# 1        Judo Men's Extra-Lightweight   NaN
# 2             Football Men's Football   NaN
# 3         Tug-Of-War Men's Tug-Of-War  Gold
# 4    Speed Skating Women's 500 metres   NaN
# 5  Speed Skating Women's 1,000 metres   NaN
# 6    Speed Skating Women's 500 metres   NaN
# 7  Speed Skating Women's 1,000 metres   NaN
# 8    Speed Skating Women's 500 metres   NaN
# 9  Speed Skating Women's 1,000 metres   NaN

# %%
#convert the .csv file to .json file
df.to_json("athlete_events1.json", orient="records")
df_json1 = pd.read_json("athlete_events1.json")

#print first 10 records
df_json1.head(10)
# Out:
#    ID                      Name Sex   Age  Height  Weight            Team  \
# 0   1                 A Dijiang   M  24.0   180.0    80.0           China
# 1   2                  A Lamusi   M  23.0   170.0    60.0           China
# 2   3       Gunnar Nielsen Aaby   M  24.0     NaN     NaN         Denmark
# 3   4      Edgar Lindenau Aabye   M  34.0     NaN     NaN  Denmark/Sweden
# 4   5  Christine Jacoba Aaftink   F  21.0   185.0    82.0     Netherlands
# 5   5  Christine Jacoba Aaftink   F  21.0   185.0    82.0     Netherlands
# 6   5  Christine Jacoba Aaftink   F  25.0   185.0    82.0     Netherlands
# 7   5  Christine Jacoba Aaftink   F  25.0   185.0    82.0     Netherlands
# 8   5  Christine Jacoba Aaftink   F  27.0   185.0    82.0     Netherlands
# 9   5  Christine Jacoba Aaftink   F  27.0   185.0    82.0     Netherlands
#
#    NOC        Games  Year  Season         City          Sport  \
# 0  CHN  1992 Summer  1992  Summer    Barcelona     Basketball
# 1  CHN  2012 Summer  2012  Summer       London           Judo
# 2  DEN  1920 Summer  1920  Summer    Antwerpen       Football
# 3  DEN  1900 Summer  1900  Summer        Paris     Tug-Of-War
# 4  NED  1988 Winter  1988  Winter      Calgary  Speed Skating
# 5  NED  1988 Winter  1988  Winter      Calgary  Speed Skating
# 6  NED  1992 Winter  1992  Winter  Albertville  Speed Skating
# 7  NED  1992 Winter  1992  Winter  Albertville  Speed Skating
# 8  NED  1994 Winter  1994  Winter  Lillehammer  Speed Skating
# 9  NED  1994 Winter  1994  Winter  Lillehammer  Speed Skating
#
#                                 Event Medal
# 0         Basketball Men's Basketball  None
# 1        Judo Men's Extra-Lightweight  None
# 2             Football Men's Football  None
# 3         Tug-Of-War Men's Tug-Of-War  Gold
# 4    Speed Skating Women's 500 metres  None
# 5  Speed Skating Women's 1,000 metres  None
# 6    Speed Skating Women's 500 metres  None
# 7  Speed Skating Women's 1,000 metres  None
# 8    Speed Skating Women's 500 metres  None
# 9  Speed Skating Women's 1,000 metres  None

# %%
#DATA CLEANING

#find sum of duplicate records in the dataset
print(df_json1.duplicated().sum())
# Out:
# 1385

# %%
#delete the duplicates
df_json1 = df_json1.drop_duplicates()
print(df_json1.duplicated().sum())
# Out:
# 0

# %%
#printing the info inorder to know the datatype of each column
print(df_json1.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 269731 entries, 0 to 271115
# Data columns (total 15 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   ID      269731 non-null  int64
#  1   Name    269731 non-null  object
#  2   Sex     269731 non-null  object
#  3   Age     260416 non-null  float64
#  4   Height  210917 non-null  float64
#  5   Weight  208204 non-null  float64
#  6   Team    269731 non-null  object
#  7   NOC     269731 non-null  object
#  8   Games   269731 non-null  object
#  9   Year    269731 non-null  int64
#  10  Season  269731 non-null  object
#  11  City    269731 non-null  object
#  12  Sport   269731 non-null  object
#  13  Event   269731 non-null  object
#  14  Medal   39772 non-null   object
# dtypes: float64(3), int64(2), object(10)
# memory usage: 32.9+ MB
# None

# %%
#converting the "Year" column to datetime datatype
#df_json1['Year']= pd.to_datetime(df_json1['Year'])

# %%
#printing the 'now correct' datatypes
print(df_json1.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 269731 entries, 0 to 271115
# Data columns (total 15 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   ID      269731 non-null  int64
#  1   Name    269731 non-null  object
#  2   Sex     269731 non-null  object
#  3   Age     260416 non-null  float64
#  4   Height  210917 non-null  float64
#  5   Weight  208204 non-null  float64
#  6   Team    269731 non-null  object
#  7   NOC     269731 non-null  object
#  8   Games   269731 non-null  object
#  9   Year    269731 non-null  int64
#  10  Season  269731 non-null  object
#  11  City    269731 non-null  object
#  12  Sport   269731 non-null  object
#  13  Event   269731 non-null  object
#  14  Medal   39772 non-null   object
# dtypes: float64(3), int64(2), object(10)
# memory usage: 32.9+ MB
# None

# %%
#checking if dataset contains any null values and printing the sum of them
print(df_json1.isnull().sum())
# Out:
# ID             0
# Name           0
# Sex            0
# Age         9315
# Height     58814
# Weight     61527
# Team           0
# NOC            0
# Games          0
# Year           0
# Season         0
# City           0
# Sport          0
# Event          0
# Medal     229959
# dtype: int64

# %%
#Handle missing age
#group the cloumns based on Name
group_columns = ['Name']

#iterate through each group based on Name
for group_keys, group_indices in df_json1.groupby(group_columns).groups.items():
    #sort by year
    group = df_json1.loc[group_indices].sort_values('Year')

    #iterate to find if the age is missing
    for i in range (len(group)):
        if pd.isnull(group.iloc[i]['Age']):
            #if age is known for previous row
            if i >0 and not pd.isnull(group.iloc[i-1]['Age']):
                year_diff = group.iloc[i]['Year'] - group.iloc[i-1]['Year']
                #year difference is then ADDED with previous given age
                df_json1.loc[group_indices[i],'Age']= group.iloc[i-1]['Age'] + year_diff

            #if age is known for next row
            elif i<len(group) - 1 and not pd.isnull(group.iloc[i+1]['Age']):
                year_diff = group.iloc[i+1]['Year'] - group.iloc[i]['Year']
                #year difference is then SUBTRACTED with previous given age
                df_json1.loc[group_indices[i],'Age']= group.iloc[i+1]['Age'] - year_diff

#using forward-fill and backward-fill to ensure no missing value remain 
res = df_json1.groupby(group_columns)['Age'].apply(lambda x: x.ffill().bfill())
#
df_json1['Age'] = res.droplevel(0)
print('Missing Age Handled!')
df_json1
# Out:
# Missing Age Handled!
#             ID                      Name Sex   Age  Height  Weight  \
# 0            1                 A Dijiang   M  24.0   180.0    80.0
# 1            2                  A Lamusi   M  23.0   170.0    60.0
# 2            3       Gunnar Nielsen Aaby   M  24.0     NaN     NaN
# 3            4      Edgar Lindenau Aabye   M  34.0     NaN     NaN
# 4            5  Christine Jacoba Aaftink   F  21.0   185.0    82.0
# ...        ...                       ...  ..   ...     ...     ...
# 271111  135569                Andrzej ya   M  29.0   179.0    89.0
# 271112  135570                  Piotr ya   M  27.0   176.0    59.0
# 271113  135570                  Piotr ya   M  27.0   176.0    59.0
# 271114  135571        Tomasz Ireneusz ya   M  30.0   185.0    96.0
# 271115  135571        Tomasz Ireneusz ya   M  34.0   185.0    96.0
#
#                   Team  NOC        Games  Year  Season            City  \
# 0                China  CHN  1992 Summer  1992  Summer       Barcelona
# 1                China  CHN  2012 Summer  2012  Summer          London
# 2              Denmark  DEN  1920 Summer  1920  Summer       Antwerpen
# 3       Denmark/Sweden  DEN  1900 Summer  1900  Summer           Paris
# 4          Netherlands  NED  1988 Winter  1988  Winter         Calgary
# ...                ...  ...          ...   ...     ...             ...
# 271111        Poland-1  POL  1976 Winter  1976  Winter       Innsbruck
# 271112          Poland  POL  2014 Winter  2014  Winter           Sochi
# 271113          Poland  POL  2014 Winter  2014  Winter           Sochi
# 271114          Poland  POL  1998 Winter  1998  Winter          Nagano
# 271115          Poland  POL  2002 Winter  2002  Winter  Salt Lake City
#
#                 Sport                                     Event Medal
# 0          Basketball               Basketball Men's Basketball  None
# 1                Judo              Judo Men's Extra-Lightweight  None
# 2            Football                   Football Men's Football  None
# 3          Tug-Of-War               Tug-Of-War Men's Tug-Of-War  Gold
# 4       Speed Skating          Speed Skating Women's 500 metres  None
# ...               ...                                       ...   ...
# 271111           Luge                Luge Mixed (Men)'s Doubles  None
# 271112    Ski Jumping  Ski Jumping Men's Large Hill, Individual  None
# 271113    Ski Jumping        Ski Jumping Men's Large Hill, Team  None
# 271114      Bobsleigh                      Bobsleigh Men's Four  None
# 271115      Bobsleigh                      Bobsleigh Men's Four  None
#
# [269731 rows x 15 columns]

# %% [markdown]
# We noticed that the dataset had missing values in the **"Age"** column, which needed to be addressed for accurate analysis. To resolve this, we grouped the data by **"Name"**, allowing us to work on records associated with each individual. Within each group, we sorted the data by **"Year"**, making it easier to track the chronological progression of ages. For rows with missing ages, we applied a logical approach to estimate their values. If the previous record in the group had a known age, we calculated the difference in years and added it to the previous age. If the previous record wasn’t available or didn’t have a known age, we used the next record instead, subtracting the year difference to estimate the missing age. After filling as many gaps as possible, we applied forward-fill and backward-fill within each group to ensure no missing values remained. Finally, we updated the dataset with the completed "Age" values, leaving it fully prepared for further analysis.

# %%
#print to check how many missing age values are handled
print(df_json1.isnull().sum())
# Out:
# ID             0
# Name           0
# Sex            0
# Age         9233
# Height     58814
# Weight     61527
# Team           0
# NOC            0
# Games          0
# Year           0
# Season         0
# City           0
# Sport          0
# Event          0
# Medal     229959
# dtype: int64

# %%
#copying the same height and weight as found for the person having 'notnull' records
#assuming height and weight does not change as athletes prefer playing in their given zone
df_json1['Height'] = df_json1.groupby('Name')['Height'].transform(lambda y : y.ffill().bfill())
df_json1['Weight'] = df_json1.groupby('Name')['Weight'].transform(lambda z : z.ffill().bfill())

# %%
#print to check how many missing height and weight values are handled
print(df_json1.isnull().sum())
# Out:
# ID             0
# Name           0
# Sex            0
# Age         9233
# Height     58426
# Weight     61138
# Team           0
# NOC            0
# Games          0
# Year           0
# Season         0
# City           0
# Sport          0
# Event          0
# Medal     229959
# dtype: int64

# %%
#creating a new column 'Age_Group' to divide them into categories of 4
df_json1["Age_Group"] = pd.cut(df_json1["Age"], bins=[1,18,25,35,100], labels=["0-18","19-25","26-35","36+"])
df_json1.head(10)
# Out:
#    ID                      Name Sex   Age  Height  Weight            Team  \
# 0   1                 A Dijiang   M  24.0   180.0    80.0           China
# 1   2                  A Lamusi   M  23.0   170.0    60.0           China
# 2   3       Gunnar Nielsen Aaby   M  24.0     NaN     NaN         Denmark
# 3   4      Edgar Lindenau Aabye   M  34.0     NaN     NaN  Denmark/Sweden
# 4   5  Christine Jacoba Aaftink   F  21.0   185.0    82.0     Netherlands
# 5   5  Christine Jacoba Aaftink   F  21.0   185.0    82.0     Netherlands
# 6   5  Christine Jacoba Aaftink   F  25.0   185.0    82.0     Netherlands
# 7   5  Christine Jacoba Aaftink   F  25.0   185.0    82.0     Netherlands
# 8   5  Christine Jacoba Aaftink   F  27.0   185.0    82.0     Netherlands
# 9   5  Christine Jacoba Aaftink   F  27.0   185.0    82.0     Netherlands
#
#    NOC        Games  Year  Season         City          Sport  \
# 0  CHN  1992 Summer  1992  Summer    Barcelona     Basketball
# 1  CHN  2012 Summer  2012  Summer       London           Judo
# 2  DEN  1920 Summer  1920  Summer    Antwerpen       Football
# 3  DEN  1900 Summer  1900  Summer        Paris     Tug-Of-War
# 4  NED  1988 Winter  1988  Winter      Calgary  Speed Skating
# 5  NED  1988 Winter  1988  Winter      Calgary  Speed Skating
# 6  NED  1992 Winter  1992  Winter  Albertville  Speed Skating
# 7  NED  1992 Winter  1992  Winter  Albertville  Speed Skating
# 8  NED  1994 Winter  1994  Winter  Lillehammer  Speed Skating
# 9  NED  1994 Winter  1994  Winter  Lillehammer  Speed Skating
#
#                                 Event Medal Age_Group
# 0         Basketball Men's Basketball  None     19-25
# 1        Judo Men's Extra-Lightweight  None     19-25
# 2             Football Men's Football  None     19-25
# 3         Tug-Of-War Men's Tug-Of-War  Gold     26-35
# 4    Speed Skating Women's 500 metres  None     19-25
# 5  Speed Skating Women's 1,000 metres  None     19-25
# 6    Speed Skating Women's 500 metres  None     19-25
# 7  Speed Skating Women's 1,000 metres  None     19-25
# 8    Speed Skating Women's 500 metres  None     26-35
# 9  Speed Skating Women's 1,000 metres  None     26-35

# %%
#creating a new column 'Century'
#subtract 1 from year so year like 2000 will be in 20th century
df_json1['Century'] = (df_json1['Year'] - 1) // 100 + 1
def add_suffix(century):
    #check the last 2 digits in order to add suffix, for eg: 11th, 12th, 13th
    if 11 <= century % 100 <= 13: 
        return f"{century}th"
    last_digit = century % 10
    if last_digit == 1:
        return f"{century}st"
    elif last_digit == 2:
        return f"{century}nd"
    elif last_digit == 3:
        return f"{century}rd"
    else:
        return f"{century}th"

#append the values to existing 'Century' column
df_json1['Century'] = df_json1['Century'].apply(add_suffix)
df_json1.head(10)
# Out:
#    ID                      Name Sex   Age  Height  Weight            Team  \
# 0   1                 A Dijiang   M  24.0   180.0    80.0           China
# 1   2                  A Lamusi   M  23.0   170.0    60.0           China
# 2   3       Gunnar Nielsen Aaby   M  24.0     NaN     NaN         Denmark
# 3   4      Edgar Lindenau Aabye   M  34.0     NaN     NaN  Denmark/Sweden
# 4   5  Christine Jacoba Aaftink   F  21.0   185.0    82.0     Netherlands
# 5   5  Christine Jacoba Aaftink   F  21.0   185.0    82.0     Netherlands
# 6   5  Christine Jacoba Aaftink   F  25.0   185.0    82.0     Netherlands
# 7   5  Christine Jacoba Aaftink   F  25.0   185.0    82.0     Netherlands
# 8   5  Christine Jacoba Aaftink   F  27.0   185.0    82.0     Netherlands
# 9   5  Christine Jacoba Aaftink   F  27.0   185.0    82.0     Netherlands
#
#    NOC        Games  Year  Season         City          Sport  \
# 0  CHN  1992 Summer  1992  Summer    Barcelona     Basketball
# 1  CHN  2012 Summer  2012  Summer       London           Judo
# 2  DEN  1920 Summer  1920  Summer    Antwerpen       Football
# 3  DEN  1900 Summer  1900  Summer        Paris     Tug-Of-War
# 4  NED  1988 Winter  1988  Winter      Calgary  Speed Skating
# 5  NED  1988 Winter  1988  Winter      Calgary  Speed Skating
# 6  NED  1992 Winter  1992  Winter  Albertville  Speed Skating
# 7  NED  1992 Winter  1992  Winter  Albertville  Speed Skating
# 8  NED  1994 Winter  1994  Winter  Lillehammer  Speed Skating
# 9  NED  1994 Winter  1994  Winter  Lillehammer  Speed Skating
#
#                                 Event Medal Age_Group Century
# 0         Basketball Men's Basketball  None     19-25    20th
# 1        Judo Men's Extra-Lightweight  None     19-25    21st
# 2             Football Men's Football  None     19-25    20th
# 3         Tug-Of-War Men's Tug-Of-War  Gold     26-35    19th
# 4    Speed Skating Women's 500 metres  None     19-25    20th
# 5  Speed Skating Women's 1,000 metres  None     19-25    20th
# 6    Speed Skating Women's 500 metres  None     19-25    20th
# 7  Speed Skating Women's 1,000 metres  None     19-25    20th
# 8    Speed Skating Women's 500 metres  None     26-35    20th
# 9  Speed Skating Women's 1,000 metres  None     26-35    20th

# %% [markdown]
# We created a new column called **"Century"** to categorize the years in the dataset by their respective centuries. To ensure that years like 2000 were correctly assigned to the 20th century, we subtracted 1 from the year before performing integer division by 100 and adding 1. This calculated the numerical century for each year. Next, we defined a function called `add_suffix` to append the appropriate suffix (e.g., "st," "nd," "rd," or "th") to each century value. The function checked the last two digits of the century to handle special cases like 11th, 12th, and 13th correctly. For other values, it determined the suffix based on the last digit (e.g., 1st, 2nd, 3rd). Finally, we applied this function to the **"Century"** column to append the suffixes to the numerical values, resulting in a properly formatted and meaningful **"Century"** column. The updated dataset was displayed using `head(10)` to verify the results.

# %%
#Identify records with negative Age

import numpy as np

negative_age_records = df_json1[df_json1['Age'] < 0]

#Replace negative Age values with NaN
df_json1.loc[df_json1['Age'] < 0, 'Age'] = np.nan

#sorting the values by age and pushing all the NaN values to the last of dataset
df_json1.sort_values(by='Age', na_position='last').head(50)
# Out:
#             ID                                             Name Sex   Age  \
# 45429    23439                                     Eugne Coulon   M   0.0
# 81773    41516                         Francisco Gonzlez Suaste   M   1.0
# 102622   51917                                     Viktor Ilyin   M   4.0
# 154785   77702                                   James McKenzie   M   4.0
# 154784   77701                                   James McKenzie   M   4.0
# 156926   78823                                    Pedro Mercado   M   5.0
# 101943   51561                                  Mohamed Ibrahim   M   6.0
# 256154  128257                                      Hugo Walser   M   8.0
# 135346   68101                                     Lee Sang-Hun   M  10.0
# 142882   71691                               Dimitrios Loundras   M  10.0
# 73461    37333                  Carlos Bienvenido Front Barrera   M  11.0
# 237141  118925  Megan Olwen Devenish Taylor (-Mandeville-Ellis)   F  11.0
# 94058    47618       Sonja Henie (-Topping, -Gardiner, -Onstad)   F  11.0
# 102916   52070                                     Etsuko Inada   F  11.0
# 252230  126307                                     Liana Vicens   F  11.0
# 140650   70616                                       Liu Luyang   F  11.0
# 252232  126307                                     Liana Vicens   F  11.0
# 252233  126307                                     Liana Vicens   F  11.0
# 101378   51268                                   Beatrice Hutiu   F  11.0
# 152798   76675                                Marcelle Matthews   F  11.0
# 79024    40129                                 Luigina Giavotti   F  11.0
# 252231  126307                                     Liana Vicens   F  11.0
# 43468    22411                       Magdalena Cecilia Colledge   F  11.0
# 251495  125944                                     Ines Vercesi   F  12.0
# 97086    49142                                     Jan Hoffmann   M  12.0
# 236977  118832                             Chin Say "Molly" Tay   F  12.0
# 118048   59727                   Marika Kilius (-Zahn, -Schfer)   F  12.0
# 96236    48728                                   Margery Hinton   F  12.0
# 60911    31203                     Patricia Anne "Pat" Eastwood   F  12.0
# 79352    40296                                 Alain C. Giletti   M  12.0
# 85840    43528                   Antoinette Joyce Guedia Mouafo   F  12.0
# 226019  113580                            Inge Srensen (-Tabur)   F  12.0
# 126542   63816                            Carolyn Patricia Krau   F  12.0
# 93850    47506                                     Hem Reaksmey   F  12.0
# 197894   99362                             Antonia Real Horrach   F  12.0
# 91913    46578                                     Diana Hatler   F  12.0
# 91912    46578                                     Diana Hatler   F  12.0
# 91911    46578                                     Diana Hatler   F  12.0
# 91910    46578                                     Diana Hatler   F  12.0
# 148942   74712                                  Carla Marangoni   F  12.0
# 145150   72854                                   Licia Macchini   F  12.0
# 120234   60854                                       Judit Kiss   F  12.0
# 120233   60854                                       Judit Kiss   F  12.0
# 168941   84913                                   Clstine N'Drin   F  12.0
# 168942   84913                                   Clstine N'Drin   F  12.0
# 149033   74755               Luciana Marcellini Hercolani Gaddi   F  12.0
# 50294    25877                   Olga Lucia de Angulo Irragorri   F  12.0
# 253662  127018         Yelena Germanovna Vodorezova (-Buyanova)   F  12.0
# 96665    48939                                          Ho Gang   M  12.0
# 50293    25877                   Olga Lucia de Angulo Irragorri   F  12.0
#
#         Height  Weight                               Team  NOC        Games  \
# 45429      NaN     NaN  Pupilles de Neptune de Lille #2-1  FRA  1900 Summer
# 81773    185.0    71.0                             Mexico  MEX  1948 Summer
# 102622   160.0    60.0                       Soviet Union  URS  1972 Winter
# 154785     NaN     NaN                      Great Britain  GBR  1908 Summer
# 154784     NaN     NaN                      Great Britain  GBR  1924 Summer
# 156926     NaN     NaN                          Argentina  ARG  1952 Summer
# 101943     NaN     NaN                              Egypt  EGY  1948 Summer
# 256154   185.0    67.0                      Liechtenstein  LIE  1964 Summer
# 135346   169.0    54.0                        South Korea  KOR  1948 Summer
# 142882     NaN     NaN      Ethnikos Gymnastikos Syllogos  GRE  1896 Summer
# 73461      NaN     NaN                              Spain  ESP  1992 Summer
# 237141   157.0     NaN                      Great Britain  GBR  1932 Winter
# 94058    155.0    45.0                             Norway  NOR  1924 Winter
# 102916     NaN     NaN                              Japan  JPN  1936 Winter
# 252230   158.0    50.0                        Puerto Rico  PUR  1968 Summer
# 140650     NaN     NaN                              China  CHN  1988 Winter
# 252232   158.0    50.0                        Puerto Rico  PUR  1968 Summer
# 252233   158.0    50.0                        Puerto Rico  PUR  1968 Summer
# 101378   151.0    38.0                            Romania  ROU  1968 Winter
# 152798     NaN     NaN                       South Africa  RSA  1960 Winter
# 79024      NaN     NaN                              Italy  ITA  1928 Summer
# 252231   158.0    50.0                        Puerto Rico  PUR  1968 Summer
# 43468    152.0     NaN                      Great Britain  GBR  1932 Winter
# 251495     NaN     NaN                              Italy  ITA  1928 Summer
# 97086    178.0    73.0                       East Germany  GDR  1968 Winter
# 236977   145.0    41.0                           Malaysia  MAS  1964 Summer
# 118048   168.0    51.0                            Germany  GER  1956 Winter
# 96236    168.0     NaN                      Great Britain  GBR  1928 Summer
# 60911      NaN     NaN                       South Africa  RSA  1960 Winter
# 79352      NaN     NaN                             France  FRA  1952 Winter
# 85840    170.0    55.0                           Cameroon  CMR  2008 Summer
# 226019     NaN     NaN                            Denmark  DEN  1936 Summer
# 126542   137.0    36.0                    Great Britain-2  GBR  1956 Winter
# 93850    175.0    65.0                           Cambodia  CAM  1996 Summer
# 197894   160.0    50.0                              Spain  ESP  1976 Summer
# 91913    164.0    46.0                        Puerto Rico  PUR  1976 Summer
# 91912    164.0    46.0                        Puerto Rico  PUR  1976 Summer
# 91911    164.0    46.0                        Puerto Rico  PUR  1976 Summer
# 91910    164.0    46.0                        Puerto Rico  PUR  1976 Summer
# 148942     NaN     NaN                              Italy  ITA  1928 Summer
# 145150     NaN     NaN                              Italy  ITA  1948 Summer
# 120234   171.0    57.0                            Hungary  HUN  1992 Summer
# 120233   171.0    57.0                            Hungary  HUN  1992 Summer
# 168941   169.0    56.0                      Cote d'Ivoire  CIV  1976 Summer
# 168942   169.0    56.0                      Cote d'Ivoire  CIV  1976 Summer
# 149033   163.0    58.0                              Italy  ITA  1960 Summer
# 50294    160.0    60.0                           Colombia  COL  1968 Summer
# 253662   161.0    47.0                       Soviet Union  URS  1976 Winter
# 96665      NaN     NaN                        North Korea  PRK  1988 Winter
# 50293    160.0    60.0                           Colombia  COL  1968 Summer
#
#         Year  Season                    City           Sport  \
# 45429   1900  Summer                   Paris      Water Polo
# 81773   1948  Summer                  London       Athletics
# 102622  1972  Winter                 Sapporo            Luge
# 154785  1908  Summer                  London       Wrestling
# 154784  1924  Summer                   Paris          Boxing
# 156926  1952  Summer                Helsinki   Equestrianism
# 101943  1948  Summer                  London          Diving
# 256154  1964  Summer                   Tokyo       Athletics
# 135346  1948  Summer                  London      Basketball
# 142882  1896  Summer                  Athina      Gymnastics
# 73461   1992  Summer               Barcelona          Rowing
# 237141  1932  Winter             Lake Placid  Figure Skating
# 94058   1924  Winter                Chamonix  Figure Skating
# 102916  1936  Winter  Garmisch-Partenkirchen  Figure Skating
# 252230  1968  Summer             Mexico City        Swimming
# 140650  1988  Winter                 Calgary  Figure Skating
# 252232  1968  Summer             Mexico City        Swimming
# 252233  1968  Summer             Mexico City        Swimming
# 101378  1968  Winter                Grenoble  Figure Skating
# 152798  1960  Winter            Squaw Valley  Figure Skating
# 79024   1928  Summer               Amsterdam      Gymnastics
# 252231  1968  Summer             Mexico City        Swimming
# 43468   1932  Winter             Lake Placid  Figure Skating
# 251495  1928  Summer               Amsterdam      Gymnastics
# 97086   1968  Winter                Grenoble  Figure Skating
# 236977  1964  Summer                   Tokyo        Swimming
# 118048  1956  Winter       Cortina d'Ampezzo  Figure Skating
# 96236   1928  Summer               Amsterdam        Swimming
# 60911   1960  Winter            Squaw Valley  Figure Skating
# 79352   1952  Winter                    Oslo  Figure Skating
# 85840   2008  Summer                 Beijing        Swimming
# 226019  1936  Summer                  Berlin        Swimming
# 126542  1956  Winter       Cortina d'Ampezzo  Figure Skating
# 93850   1996  Summer                 Atlanta        Swimming
# 197894  1976  Summer                Montreal        Swimming
# 91913   1976  Summer                Montreal        Swimming
# 91912   1976  Summer                Montreal        Swimming
# 91911   1976  Summer                Montreal        Swimming
# 91910   1976  Summer                Montreal        Swimming
# 148942  1928  Summer               Amsterdam      Gymnastics
# 145150  1948  Summer                  London      Gymnastics
# 120234  1992  Summer               Barcelona        Swimming
# 120233  1992  Summer               Barcelona        Swimming
# 168941  1976  Summer                Montreal       Athletics
# 168942  1976  Summer                Montreal       Athletics
# 149033  1960  Summer                    Roma        Swimming
# 50294   1968  Summer             Mexico City        Swimming
# 253662  1976  Winter               Innsbruck  Figure Skating
# 96665   1988  Winter                 Calgary  Figure Skating
# 50293   1968  Summer             Mexico City        Swimming
#
#                                                   Event   Medal Age_Group  \
# 45429                       Water Polo Men's Water Polo  Bronze       NaN
# 81773                      Athletics Men's Hammer Throw    None       NaN
# 102622                               Luge Men's Singles    None      0-18
# 154785           Wrestling Men's Lightweight, Freestyle    None      0-18
# 154784                           Boxing Men's Flyweight  Silver      0-18
# 156926  Equestrianism Men's Three-Day Event, Individual    None      0-18
# 101943                         Diving Men's Springboard    None      0-18
# 256154                       Athletics Men's 800 metres    None      0-18
# 135346                      Basketball Men's Basketball    None      0-18
# 142882            Gymnastics Men's Parallel Bars, Teams  Bronze      0-18
# 73461                         Rowing Men's Coxed Eights    None      0-18
# 237141                   Figure Skating Women's Singles    None      0-18
# 94058                    Figure Skating Women's Singles    None      0-18
# 102916                   Figure Skating Women's Singles    None      0-18
# 252230         Swimming Women's 100 metres Breaststroke    None      0-18
# 140650                 Figure Skating Mixed Ice Dancing    None      0-18
# 252232    Swimming Women's 200 metres Individual Medley    None      0-18
# 252233     Swimming Women's 4 x 100 metres Medley Relay    None      0-18
# 101378                   Figure Skating Women's Singles    None      0-18
# 152798                       Figure Skating Mixed Pairs    None      0-18
# 79024                Gymnastics Women's Team All-Around  Silver      0-18
# 252231         Swimming Women's 200 metres Breaststroke    None      0-18
# 43468                    Figure Skating Women's Singles    None      0-18
# 251495               Gymnastics Women's Team All-Around  Silver      0-18
# 97086                      Figure Skating Men's Singles    None      0-18
# 236977            Swimming Women's 100 metres Butterfly    None      0-18
# 118048                       Figure Skating Mixed Pairs    None      0-18
# 96236          Swimming Women's 200 metres Breaststroke    None      0-18
# 60911                    Figure Skating Women's Singles    None      0-18
# 79352                      Figure Skating Men's Singles    None      0-18
# 85840              Swimming Women's 50 metres Freestyle    None      0-18
# 226019         Swimming Women's 200 metres Breaststroke  Bronze      0-18
# 126542                       Figure Skating Mixed Pairs    None      0-18
# 93850          Swimming Women's 100 metres Breaststroke    None      0-18
# 197894            Swimming Women's 400 metres Freestyle    None      0-18
# 91913      Swimming Women's 4 x 100 metres Medley Relay    None      0-18
# 91912   Swimming Women's 4 x 100 metres Freestyle Relay    None      0-18
# 91911             Swimming Women's 800 metres Freestyle    None      0-18
# 91910             Swimming Women's 400 metres Freestyle    None      0-18
# 148942               Gymnastics Women's Team All-Around  Silver      0-18
# 145150               Gymnastics Women's Team All-Around    None      0-18
# 120234            Swimming Women's 800 metres Freestyle    None      0-18
# 120233            Swimming Women's 400 metres Freestyle    None      0-18
# 168941                     Athletics Women's 400 metres    None      0-18
# 168942                     Athletics Women's 800 metres    None      0-18
# 149033         Swimming Women's 200 metres Breaststroke    None      0-18
# 50294     Swimming Women's 400 metres Individual Medley    None      0-18
# 253662                   Figure Skating Women's Singles    None      0-18
# 96665                      Figure Skating Men's Singles    None      0-18
# 50293     Swimming Women's 200 metres Individual Medley    None      0-18
#
#        Century
# 45429     19th
# 81773     20th
# 102622    20th
# 154785    20th
# 154784    20th
# 156926    20th
# 101943    20th
# 256154    20th
# 135346    20th
# 142882    19th
# 73461     20th
# 237141    20th
# 94058     20th
# 102916    20th
# 252230    20th
# 140650    20th
# 252232    20th
# 252233    20th
# 101378    20th
# 152798    20th
# 79024     20th
# 252231    20th
# 43468     20th
# 251495    20th
# 97086     20th
# 236977    20th
# 118048    20th
# 96236     20th
# 60911     20th
# 79352     20th
# 85840     21st
# 226019    20th
# 126542    20th
# 93850     20th
# 197894    20th
# 91913     20th
# 91912     20th
# 91911     20th
# 91910     20th
# 148942    20th
# 145150    20th
# 120234    20th
# 120233    20th
# 168941    20th
# 168942    20th
# 149033    20th
# 50294     20th
# 253662    20th
# 96665     20th
# 50293     20th

# %% [markdown]
# To address inconsistencies in the **"Age"** column, we identified records where the age had a negative value. Using a filter, we created a subset of the dataset containing only the rows with **negative Age** values. Recognizing that negative ages were invalid, we replaced these values with **NaN** (Not a Number) to signify missing or undefined data. After making these adjustments, we sorted the dataset by **"Age"**, ensuring that all rows with NaN values were pushed to the end of the dataset. Finally, we used `head(50)` to display the first 50 records, verifying that the data was cleaned and properly sorted.

# %%
#Some of the ages of records dont make sense, for eg: age cannot be 0 and 1 year olds cannot compete in olympics
#So we are taking one minimum age to clean the data
#If you disagree feel free to change the minimum age

min_age = 11
df_json1.loc[df_json1['Age'] < min_age, 'Age'] = np.nan

# %%
df_json1.sort_values(by='Age', na_position='last').head(50)
# Out:
#             ID                                               Name Sex   Age  \
# 237141  118925    Megan Olwen Devenish Taylor (-Mandeville-Ellis)   F  11.0
# 152798   76675                                  Marcelle Matthews   F  11.0
# 73461    37333                    Carlos Bienvenido Front Barrera   M  11.0
# 94058    47618         Sonja Henie (-Topping, -Gardiner, -Onstad)   F  11.0
# 252230  126307                                       Liana Vicens   F  11.0
# 252231  126307                                       Liana Vicens   F  11.0
# 102916   52070                                       Etsuko Inada   F  11.0
# 101378   51268                                     Beatrice Hutiu   F  11.0
# 140650   70616                                         Liu Luyang   F  11.0
# 43468    22411                         Magdalena Cecilia Colledge   F  11.0
# 252232  126307                                       Liana Vicens   F  11.0
# 252233  126307                                       Liana Vicens   F  11.0
# 79024    40129                                   Luigina Giavotti   F  11.0
# 91911    46578                                       Diana Hatler   F  12.0
# 253662  127018           Yelena Germanovna Vodorezova (-Buyanova)   F  12.0
# 85840    43528                     Antoinette Joyce Guedia Mouafo   F  12.0
# 93850    47506                                       Hem Reaksmey   F  12.0
# 226019  113580                              Inge Srensen (-Tabur)   F  12.0
# 50294    25877                     Olga Lucia de Angulo Irragorri   F  12.0
# 50293    25877                     Olga Lucia de Angulo Irragorri   F  12.0
# 50291    25877                     Olga Lucia de Angulo Irragorri   F  12.0
# 79352    40296                                   Alain C. Giletti   M  12.0
# 168941   84913                                     Clstine N'Drin   F  12.0
# 168942   84913                                     Clstine N'Drin   F  12.0
# 251495  125944                                       Ines Vercesi   F  12.0
# 96665    48939                                            Ho Gang   M  12.0
# 197895   99362                               Antonia Real Horrach   F  12.0
# 60911    31203                       Patricia Anne "Pat" Eastwood   F  12.0
# 149033   74755                 Luciana Marcellini Hercolani Gaddi   F  12.0
# 108031   54620  Belita Gladys Lyne Jepson Turner (-Riordan, -K...   F  12.0
# 145150   72854                                     Licia Macchini   F  12.0
# 197894   99362                               Antonia Real Horrach   F  12.0
# 249804  125092                       tienne Nol Henri Vandernotte   M  12.0
# 249803  125092                       tienne Nol Henri Vandernotte   M  12.0
# 84361    42835                                  Werner Grieshofer   M  12.0
# 96236    48728                                     Margery Hinton   F  12.0
# 148942   74712                                    Carla Marangoni   F  12.0
# 91912    46578                                       Diana Hatler   F  12.0
# 50292    25877                     Olga Lucia de Angulo Irragorri   F  12.0
# 46955    24191                                Philippe Cuelenaere   M  12.0
# 192507   96664                     Dorothy Poynton-Hill (-Teuber)   F  12.0
# 118048   59727                     Marika Kilius (-Zahn, -Schfer)   F  12.0
# 236977  118832                               Chin Say "Molly" Tay   F  12.0
# 126542   63816                              Carolyn Patricia Krau   F  12.0
# 9650      5291                            Marcia Arriaga Larrinua   F  12.0
# 97086    49142                                       Jan Hoffmann   M  12.0
# 91913    46578                                       Diana Hatler   F  12.0
# 9649      5291                            Marcia Arriaga Larrinua   F  12.0
# 9648      5291                            Marcia Arriaga Larrinua   F  12.0
# 120233   60854                                         Judit Kiss   F  12.0
#
#         Height  Weight             Team  NOC        Games  Year  Season  \
# 237141   157.0     NaN    Great Britain  GBR  1932 Winter  1932  Winter
# 152798     NaN     NaN     South Africa  RSA  1960 Winter  1960  Winter
# 73461      NaN     NaN            Spain  ESP  1992 Summer  1992  Summer
# 94058    155.0    45.0           Norway  NOR  1924 Winter  1924  Winter
# 252230   158.0    50.0      Puerto Rico  PUR  1968 Summer  1968  Summer
# 252231   158.0    50.0      Puerto Rico  PUR  1968 Summer  1968  Summer
# 102916     NaN     NaN            Japan  JPN  1936 Winter  1936  Winter
# 101378   151.0    38.0          Romania  ROU  1968 Winter  1968  Winter
# 140650     NaN     NaN            China  CHN  1988 Winter  1988  Winter
# 43468    152.0     NaN    Great Britain  GBR  1932 Winter  1932  Winter
# 252232   158.0    50.0      Puerto Rico  PUR  1968 Summer  1968  Summer
# 252233   158.0    50.0      Puerto Rico  PUR  1968 Summer  1968  Summer
# 79024      NaN     NaN            Italy  ITA  1928 Summer  1928  Summer
# 91911    164.0    46.0      Puerto Rico  PUR  1976 Summer  1976  Summer
# 253662   161.0    47.0     Soviet Union  URS  1976 Winter  1976  Winter
# 85840    170.0    55.0         Cameroon  CMR  2008 Summer  2008  Summer
# 93850    175.0    65.0         Cambodia  CAM  1996 Summer  1996  Summer
# 226019     NaN     NaN          Denmark  DEN  1936 Summer  1936  Summer
# 50294    160.0    60.0         Colombia  COL  1968 Summer  1968  Summer
# 50293    160.0    60.0         Colombia  COL  1968 Summer  1968  Summer
# 50291    160.0    60.0         Colombia  COL  1968 Summer  1968  Summer
# 79352      NaN     NaN           France  FRA  1952 Winter  1952  Winter
# 168941   169.0    56.0    Cote d'Ivoire  CIV  1976 Summer  1976  Summer
# 168942   169.0    56.0    Cote d'Ivoire  CIV  1976 Summer  1976  Summer
# 251495     NaN     NaN            Italy  ITA  1928 Summer  1928  Summer
# 96665      NaN     NaN      North Korea  PRK  1988 Winter  1988  Winter
# 197895   160.0    50.0            Spain  ESP  1976 Summer  1976  Summer
# 60911      NaN     NaN     South Africa  RSA  1960 Winter  1960  Winter
# 149033   163.0    58.0            Italy  ITA  1960 Summer  1960  Summer
# 108031   166.0     NaN    Great Britain  GBR  1936 Winter  1936  Winter
# 145150     NaN     NaN            Italy  ITA  1948 Summer  1948  Summer
# 197894   160.0    50.0            Spain  ESP  1976 Summer  1976  Summer
# 249804     NaN    37.0           France  FRA  1936 Summer  1936  Summer
# 249803     NaN    37.0           France  FRA  1936 Summer  1936  Summer
# 84361    170.0    48.0          Austria  AUT  1972 Summer  1972  Summer
# 96236    168.0     NaN    Great Britain  GBR  1928 Summer  1928  Summer
# 148942     NaN     NaN            Italy  ITA  1928 Summer  1928  Summer
# 91912    164.0    46.0      Puerto Rico  PUR  1976 Summer  1976  Summer
# 50292    160.0    60.0         Colombia  COL  1968 Summer  1968  Summer
# 46955    170.0    50.0          Belgium  BEL  1984 Summer  1984  Summer
# 192507     NaN     NaN    United States  USA  1928 Summer  1928  Summer
# 118048   168.0    51.0          Germany  GER  1956 Winter  1956  Winter
# 236977   145.0    41.0         Malaysia  MAS  1964 Summer  1964  Summer
# 126542   137.0    36.0  Great Britain-2  GBR  1956 Winter  1956  Winter
# 9650     168.0    58.0           Mexico  MEX  1968 Summer  1968  Summer
# 97086    178.0    73.0     East Germany  GDR  1968 Winter  1968  Winter
# 91913    164.0    46.0      Puerto Rico  PUR  1976 Summer  1976  Summer
# 9649     168.0    58.0           Mexico  MEX  1968 Summer  1968  Summer
# 9648     168.0    58.0           Mexico  MEX  1968 Summer  1968  Summer
# 120233   171.0    57.0          Hungary  HUN  1992 Summer  1992  Summer
#
#                           City           Sport  \
# 237141             Lake Placid  Figure Skating
# 152798            Squaw Valley  Figure Skating
# 73461                Barcelona          Rowing
# 94058                 Chamonix  Figure Skating
# 252230             Mexico City        Swimming
# 252231             Mexico City        Swimming
# 102916  Garmisch-Partenkirchen  Figure Skating
# 101378                Grenoble  Figure Skating
# 140650                 Calgary  Figure Skating
# 43468              Lake Placid  Figure Skating
# 252232             Mexico City        Swimming
# 252233             Mexico City        Swimming
# 79024                Amsterdam      Gymnastics
# 91911                 Montreal        Swimming
# 253662               Innsbruck  Figure Skating
# 85840                  Beijing        Swimming
# 93850                  Atlanta        Swimming
# 226019                  Berlin        Swimming
# 50294              Mexico City        Swimming
# 50293              Mexico City        Swimming
# 50291              Mexico City        Swimming
# 79352                     Oslo  Figure Skating
# 168941                Montreal       Athletics
# 168942                Montreal       Athletics
# 251495               Amsterdam      Gymnastics
# 96665                  Calgary  Figure Skating
# 197895                Montreal        Swimming
# 60911             Squaw Valley  Figure Skating
# 149033                    Roma        Swimming
# 108031  Garmisch-Partenkirchen  Figure Skating
# 145150                  London      Gymnastics
# 197894                Montreal        Swimming
# 249804                  Berlin          Rowing
# 249803                  Berlin          Rowing
# 84361                   Munich          Rowing
# 96236                Amsterdam        Swimming
# 148942               Amsterdam      Gymnastics
# 91912                 Montreal        Swimming
# 50292              Mexico City        Swimming
# 46955              Los Angeles          Rowing
# 192507               Amsterdam          Diving
# 118048       Cortina d'Ampezzo  Figure Skating
# 236977                   Tokyo        Swimming
# 126542       Cortina d'Ampezzo  Figure Skating
# 9650               Mexico City        Swimming
# 97086                 Grenoble  Figure Skating
# 91913                 Montreal        Swimming
# 9649               Mexico City        Swimming
# 9648               Mexico City        Swimming
# 120233               Barcelona        Swimming
#
#                                                   Event   Medal Age_Group  \
# 237141                   Figure Skating Women's Singles    None      0-18
# 152798                       Figure Skating Mixed Pairs    None      0-18
# 73461                         Rowing Men's Coxed Eights    None      0-18
# 94058                    Figure Skating Women's Singles    None      0-18
# 252230         Swimming Women's 100 metres Breaststroke    None      0-18
# 252231         Swimming Women's 200 metres Breaststroke    None      0-18
# 102916                   Figure Skating Women's Singles    None      0-18
# 101378                   Figure Skating Women's Singles    None      0-18
# 140650                 Figure Skating Mixed Ice Dancing    None      0-18
# 43468                    Figure Skating Women's Singles    None      0-18
# 252232    Swimming Women's 200 metres Individual Medley    None      0-18
# 252233     Swimming Women's 4 x 100 metres Medley Relay    None      0-18
# 79024                Gymnastics Women's Team All-Around  Silver      0-18
# 91911             Swimming Women's 800 metres Freestyle    None      0-18
# 253662                   Figure Skating Women's Singles    None      0-18
# 85840              Swimming Women's 50 metres Freestyle    None      0-18
# 93850          Swimming Women's 100 metres Breaststroke    None      0-18
# 226019         Swimming Women's 200 metres Breaststroke  Bronze      0-18
# 50294     Swimming Women's 400 metres Individual Medley    None      0-18
# 50293     Swimming Women's 200 metres Individual Medley    None      0-18
# 50291             Swimming Women's 400 metres Freestyle    None      0-18
# 79352                      Figure Skating Men's Singles    None      0-18
# 168941                     Athletics Women's 400 metres    None      0-18
# 168942                     Athletics Women's 800 metres    None      0-18
# 251495               Gymnastics Women's Team All-Around  Silver      0-18
# 96665                      Figure Skating Men's Singles    None      0-18
# 197895            Swimming Women's 800 metres Freestyle    None      0-18
# 60911                    Figure Skating Women's Singles    None      0-18
# 149033         Swimming Women's 200 metres Breaststroke    None      0-18
# 108031                   Figure Skating Women's Singles    None      0-18
# 145150               Gymnastics Women's Team All-Around    None      0-18
# 197894            Swimming Women's 400 metres Freestyle    None      0-18
# 249804                         Rowing Men's Coxed Fours  Bronze      0-18
# 249803                         Rowing Men's Coxed Pairs  Bronze      0-18
# 84361                          Rowing Men's Coxed Pairs    None      0-18
# 96236          Swimming Women's 200 metres Breaststroke    None      0-18
# 148942               Gymnastics Women's Team All-Around  Silver      0-18
# 91912   Swimming Women's 4 x 100 metres Freestyle Relay    None      0-18
# 50292             Swimming Women's 800 metres Freestyle    None      0-18
# 46955                          Rowing Men's Coxed Pairs    None      0-18
# 192507                       Diving Women's Springboard  Silver      0-18
# 118048                       Figure Skating Mixed Pairs    None      0-18
# 236977            Swimming Women's 100 metres Butterfly    None      0-18
# 126542                       Figure Skating Mixed Pairs    None      0-18
# 9650    Swimming Women's 4 x 100 metres Freestyle Relay    None      0-18
# 97086                      Figure Skating Men's Singles    None      0-18
# 91913      Swimming Women's 4 x 100 metres Medley Relay    None      0-18
# 9649              Swimming Women's 200 metres Freestyle    None      0-18
# 9648              Swimming Women's 100 metres Freestyle    None      0-18
# 120233            Swimming Women's 400 metres Freestyle    None      0-18
#
#        Century
# 237141    20th
# 152798    20th
# 73461     20th
# 94058     20th
# 252230    20th
# 252231    20th
# 102916    20th
# 101378    20th
# 140650    20th
# 43468     20th
# 252232    20th
# 252233    20th
# 79024     20th
# 91911     20th
# 253662    20th
# 85840     21st
# 93850     20th
# 226019    20th
# 50294     20th
# 50293     20th
# 50291     20th
# 79352     20th
# 168941    20th
# 168942    20th
# 251495    20th
# 96665     20th
# 197895    20th
# 60911     20th
# 149033    20th
# 108031    20th
# 145150    20th
# 197894    20th
# 249804    20th
# 249803    20th
# 84361     20th
# 96236     20th
# 148942    20th
# 91912     20th
# 50292     20th
# 46955     20th
# 192507    20th
# 118048    20th
# 236977    20th
# 126542    20th
# 9650      20th
# 97086     20th
# 91913     20th
# 9649      20th
# 9648      20th
# 120233    20th

# %%
# Calculate average age for each athlete for each event
avg_age = df_json1.groupby("Event")["Age"].mean().reset_index(name="Average Age")
#round the avg to zero decimal places
avg_age["Average Age"] = avg_age["Average Age"].round(0)

print("\nAverage Age of Athletes for Each Event:")
avg_age
# Out:
# Average Age of Athletes for Each Event:
#                                               Event  Average Age
# 0                     Aeronautics Mixed Aeronautics         26.0
# 1                      Alpine Skiing Men's Combined         24.0
# 2                      Alpine Skiing Men's Downhill         24.0
# 3                  Alpine Skiing Men's Giant Slalom         23.0
# 4                        Alpine Skiing Men's Slalom         24.0
# ..                                              ...          ...
# 760          Wrestling Women's Flyweight, Freestyle         25.0
# 761        Wrestling Women's Heavyweight, Freestyle         26.0
# 762  Wrestling Women's Light-Heavyweight, Freestyle         25.0
# 763        Wrestling Women's Lightweight, Freestyle         25.0
# 764       Wrestling Women's Middleweight, Freestyle         25.0
#
# [765 rows x 2 columns]

# %%
#count gold, silver and bronze medals, country wise
medal_summary = (
    #to summarize data in tabular format
    df_json1.pivot_table(
        index="Team", #unique value to identify
        columns="Medal",
        aggfunc="size",
        fill_value=0  #Replace missing values with 0
    )
    .reset_index() #resetting the Team column from index to regular column
)

# Rename columns for clarity
medal_summary.columns.name = None  #Remove the pivot column name
medal_summary.rename(columns={"Gold": "Gold", "Silver": "Silver", "Bronze": "Bronze"}, inplace=True)

print("\nMedal Summary by Country:")
print(medal_summary)
# Out:
# Medal Summary by Country:
#                              Team  Bronze  Gold  Silver
# 0           A North American Team       4     0       0
# 1                     Afghanistan       2     0       0
# 2                         Algeria       8     5       4
# 3                     Ali-Baba II       5     0       0
# 4    Amateur Athletic Association       0     5       0
# ..                            ...     ...   ...     ...
# 493          Winnipeg Shamrocks-1       0    12       0
# 494                    Yugoslavia      93   130     167
# 495                        Zambia       1     0       1
# 496                      Zimbabwe       1    17       4
# 497                           Zut       0     0       3
#
# [498 rows x 4 columns]

# %%
#count gold medals won by each country and display top 10
gold_medals = df_json1[df_json1['Medal']=='Gold']
gold_medal_count = gold_medals['Team'].value_counts()

top_ten_countries = gold_medal_count.head(10)
top_ten_countries
# Out:
# Team
# United States    2474
# Soviet Union     1058
# Germany           679
# Italy             535
# Great Britain     519
# France            455
# Sweden            451
# Hungary           432
# Canada            422
# East Germany      369
# Name: count, dtype: int64

# %% [markdown]
# This code and its associated insights focus on analyzing the distribution of gold medals across different countries:
#
# ### **Code Functionality**:
# - The code filters the dataset to identify records where the medal type is 'Gold'.
# - A **count of gold medals** won by each country is calculated.
# - The **top 10 countries** with the most gold medals are extracted and displayed.
#
# ### **Considerations**:
# - During the analysis, we encountered a historical nuance related to countries like the **Soviet Union**. The Soviet Union, which competed as a single entity during certain Olympic Games (e.g., 1980), has since been divided into multiple independent nations such as **Russia**, **Ukraine**, and others.
#   - A key question is whether to treat the **Soviet Union and its successor states as separate entities** or aggregate their medal counts under one umbrella.
#   - If treated separately, nations like Russia may appear to have fewer total medals compared to their historical performance as part of the Soviet Union.
#   - Conversely, countries like the **USA**, which have remained consistent in their representation over the years, might seem more dominant due to the lack of such complexities.
#
# ### **Acknowledgment**:
# - This analysis acknowledges this issue but does not combine medal counts for countries that underwent geopolitical changes. For example, the Soviet Union and Russia are treated as distinct entities in this dataset. This approach avoids subjective decisions about how to merge historical records but may impact comparative dominance in the medal standings.
# - These considerations are important to keep in mind when interpreting the **top 10 gold medal-winning countries**, as historical context plays a role in medal distribution.
#
# ### **Insights**:
# - The top-performing countries by gold medal count can be influenced by how historical entities like the Soviet Union are handled in the dataset. Further analysis or adjustments might be necessary for a more balanced comparison across nations.

# %%
#most medals won in each sport and by which player
medal_count = df_json1.groupby(['Sport', 'Name']).size().reset_index(name='Medal Count')
#identify the row where medal count is high for a given sport
top_athlete_medals = medal_count.loc[medal_count.groupby('Sport')['Medal Count'].idxmax()]
top_athlete_medals
# Out:
#                    Sport                             Name  Medal Count
# 0            Aeronautics                Hermann Schreiber            1
# 1463       Alpine Skiing               Kjetil Andr Aamodt           20
# 2735            Alpinism                   Antarge Sherpa            1
# 3067             Archery  Gerard Theodor Hubert Van Innis           11
# 4769    Art Competitions       Jean Lucien Nicolas Jacoby            9
# ...                  ...                              ...          ...
# 123503        Tug-Of-War               Edwin Archer Mills            3
# 125643        Volleyball       Sergey Yuryevich Tetyukhin            6
# 127677        Water Polo      Manuel Estiarte Duocastella            6
# 129778     Weightlifting                        Imre Fldi            5
# 136317         Wrestling                Wilfried Dietrich            8
#
# [66 rows x 3 columns]

# %%
#Medal count of countires within specified year range

# Define the year range as variables
# feel free to experiment with years
start_year = 1920
end_year = 1940

# Filter data based on the year range
filtered_df = df_json1[(df_json1["Year"] >= start_year) & (df_json1["Year"] <= end_year)]

# Group by Country and count medals within the specified range
medal_count = (
    filtered_df.groupby("Team")["Medal"]
    .count() #count non-Nan values, returns total no. of medals won by each team
    .reset_index(name="Medal Count")
    .sort_values("Medal Count", ascending=False)
)

print(f"\nMedal Count from {start_year} to {end_year}:")
medal_count
# Out:
# Medal Count from 1920 to 1940:
#               Team  Medal Count
# 225  United States          770
# 82          France          376
# 126          Italy          354
# 91         Germany          350
# 210         Sweden          338
# ..             ...          ...
# 105         Hatuey            0
# 106     Heidelberg            0
# 109        Holland            0
# 111       Hungaria            0
# 237       Zimbabwe            0
#
# [238 rows x 2 columns]

# %%
#Medal count of players along with country they represent within specified year range

# Define the year range as variables
# feel free to experiment
start_year = 1980
end_year = 2000

# Filter data based on the year range
filtered_df = df_json1[(df_json1["Year"] >= start_year) & (df_json1["Year"] <= end_year)]

# Group by Country and count medals within the specified range
medal_count = (
    filtered_df.groupby(["Name","Team"])["Medal"]
    .count() #count non-Nan values, returns total no. of medals won by each team
    .reset_index(name="Medal Count")
    .sort_values("Medal Count", ascending=False)
)

print(f"\nMedal Count from {start_year} to {end_year}:")
medal_count
# Out:
# Medal Count from 1980 to 2000:
#                                                   Name           Team  \
# 1406                           Aleksey Yuryevich Nemov         Russia
# 28646                   Matthew Nicholas "Matt" Biondi  United States
# 18940  Jennifer Elisabeth "Jenny" Thompson (-Cumpelik)  United States
# 12942                   Frederick Carlton "Carl" Lewis  United States
# 28994                         Merlene Joyce Ottey-Page        Jamaica
# ...                                                ...            ...
# 17224                      Irina Olegovna Bazilevskaya        Belarus
# 17226                           Irina Olegovna Shilova        Belarus
# 17228                           Irina Olegovna Shilova   Unified Team
# 17229                                    Irina Petcule        Romania
# 46886                                     zdemir Akbal         Turkey
#
#        Medal Count
# 1406            12
# 28646           11
# 18940           10
# 12942           10
# 28994            9
# ...            ...
# 17224            0
# 17226            0
# 17228            0
# 17229            0
# 46886            0
#
# [46887 rows x 3 columns]

# %%
#Medal count based on sport and which country has won maximum medals

medal_count = df_json1.groupby(['Sport', 'Team']).size().reset_index(name='Medal Count')
top_athlete_medals = medal_count.loc[medal_count.groupby('Sport')['Medal Count'].idxmax()]
top_athlete_medals
# Out:
#                  Sport           Team  Medal Count
# 0          Aeronautics    Switzerland            1
# 7        Alpine Skiing        Austria          556
# 104           Alpinism  Great Britain           12
# 204            Archery  United States          155
# 256   Art Competitions  United States          314
# ...                ...            ...          ...
# 4811        Tug-Of-War         Sweden           24
# 4817        Volleyball         Brazil          285
# 4881        Water Polo        Hungary          304
# 5061     Weightlifting  United States          153
# 5193         Wrestling  United States          383
#
# [66 rows x 3 columns]

# %%
print(df_json1['Season'].unique())
print(df_json1['Sex'].unique())
# Out:
# ['Summer' 'Winter']
# ['M' 'F']

# %%
import pandas as pd
import matplotlib.pyplot as plt

gender_counts = df_json1.groupby(['Season', 'Sex']).size().reset_index(name='Counts')

# Separate data for Summer and Winter
summer = gender_counts[gender_counts['Season'] == 'Summer']
winter = gender_counts[gender_counts['Season'] == 'Winter']

# Function to plot a pie chart
def plot_pie_chart(data, title):
    labels = data['Sex']
    sizes = data['Counts']
    colors = ['pink', 'blue']  # Adjust colors as needed
    explode = (0.1, 0)  # Highlight the first slice if desired

    plt.pie(sizes, labels=labels, autopct='%1.1f%%', colors=colors, explode=explode, startangle=90)
    plt.title(title)
    plt.axis('equal')  # Equal aspect ratio ensures the pie chart is circular.

# Create subplots for side-by-side pie charts
plt.figure(figsize=(12, 6))

# Summer Olympics
plt.subplot(1, 2, 1)
plot_pie_chart(summer, 'Summer Olympics Gender Distribution')

# Winter Olympics
plt.subplot(1, 2, 2)
plot_pie_chart(winter, 'Winter Olympics Gender Distribution')

# Show the plot
plt.tight_layout()
plt.show()

# %% [markdown]
# This code and visualization provide a breakdown of gender distribution in the **Summer Olympics** and **Winter Olympics** using pie charts. Here's what it shows:
#
# 1. **Data Aggregation**:
#    The dataset was grouped by **Season** (Summer or Winter) and **Sex** (Male or Female) to count the number of participants in each category. This grouped data was separated into two subsets: one for the Summer Olympics and another for the Winter Olympics.
#
# 2. **Pie Chart Visualization**:
#    The **plot_pie_chart** function was used to create pie charts displaying the proportions of male and female participants for each Olympic season. The function highlights one segment (female) using an "explode" effect, making the charts visually distinct.
#
# 3. **Comparison of Gender Distribution**:
#    - In the **Summer Olympics**, male participants accounted for **73.2%**, while female participants made up **26.8%**.
#    - In the **Winter Olympics**, male participants represented **69.0%**, and females accounted for **31.0%**.
#    The gender gap is slightly narrower in the Winter Olympics compared to the Summer Olympics.
#
# 4. **Layout**:
#    The charts are displayed side-by-side for easy comparison, with clear titles indicating the season and labels showing the percentage contribution of each gender.
#
# This visualization effectively highlights the gender distribution across the two Olympic seasons, making it easy to observe the differences in participation between males and females.

# %%
import seaborn as sns
import matplotlib.pyplot as plt


# Ensure necessary columns are present
required_columns = {'Season', 'Year', 'Team', 'Sport', 'Medal'}
if not required_columns.issubset(df_json1.columns):
    raise ValueError(f"Dataset must contain the following columns: {required_columns}")

# Filter for Summer and Winter Olympics data
summer_df = df_json1[df_json1['Season'] == 'Summer']
winter_df = df_json1[df_json1['Season'] == 'Winter']

### 1. Participation Trends ###
# Group by Year and Season, then count the number of unique participants or countries
participation_trends = df_json1.groupby(['Year', 'Season'])['Team'].nunique().reset_index(name='Unique Countries')

# Plot Participation Trends
plt.figure(figsize=(12, 6))
sns.lineplot(data=participation_trends, x='Year', y='Unique Countries', hue='Season', marker='o')
plt.title('Participation Trends: Summer vs Winter Olympics')
plt.xlabel('Year')
plt.ylabel('Number of Countries')
plt.legend(title='Olympic Season')
plt.show()

### 2. Medal Counts by Country ###
# Count medals by Country and Season
medals_by_country = df_json1[df_json1['Medal'].notnull()].groupby(['Team', 'Season'])['Medal'].count().reset_index(name='Medal Count')

# Get top 10 countries by medal count in each season
top_summer_countries = medals_by_country[medals_by_country['Season'] == 'Summer'].nlargest(10, 'Medal Count')
top_winter_countries = medals_by_country[medals_by_country['Season'] == 'Winter'].nlargest(10, 'Medal Count')

# Plot Top Countries Medal Counts
fig, axes = plt.subplots(1, 2, figsize=(16, 6), sharey=True)
sns.barplot(data=top_summer_countries, x='Medal Count', y='Team', ax=axes[0], palette='summer')
axes[0].set_title('Top 10 Countries - Summer Olympics')
sns.barplot(data=top_winter_countries, x='Medal Count', y='Team', ax=axes[1], palette='winter')
axes[1].set_title('Top 10 Countries - Winter Olympics')
plt.tight_layout()
plt.show()

### 3. Medal Counts by Sport ###
# Count medals by Sport and Season
medals_by_sport = df_json1[df_json1['Medal'].notnull()].groupby(['Sport', 'Season'])['Medal'].count().reset_index(name='Medal Count')

# Get top sports by medal count in each season
top_summer_sports = medals_by_sport[medals_by_sport['Season'] == 'Summer'].nlargest(10, 'Medal Count')
top_winter_sports = medals_by_sport[medals_by_sport['Season'] == 'Winter'].nlargest(10, 'Medal Count')

# Plot Top Sports Medal Counts
fig, axes = plt.subplots(1, 2, figsize=(16, 6), sharey=True)
sns.barplot(data=top_summer_sports, x='Medal Count', y='Sport', ax=axes[0], palette='summer')
axes[0].set_title('Top 10 Sports - Summer Olympics')
sns.barplot(data=top_winter_sports, x='Medal Count', y='Sport', ax=axes[1], palette='winter')
axes[1].set_title('Top 10 Sports - Winter Olympics')
plt.tight_layout()
plt.show()
# Out:
# C:\Users\Riddhi Shelwante\AppData\Local\Temp\ipykernel_28552\2388618874.py:37: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=top_summer_countries, x='Medal Count', y='Team', ax=axes[0], palette='summer')
# C:\Users\Riddhi Shelwante\AppData\Local\Temp\ipykernel_28552\2388618874.py:39: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=top_winter_countries, x='Medal Count', y='Team', ax=axes[1], palette='winter')
# C:\Users\Riddhi Shelwante\AppData\Local\Temp\ipykernel_28552\2388618874.py:54: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=top_summer_sports, x='Medal Count', y='Sport', ax=axes[0], palette='summer')
# C:\Users\Riddhi Shelwante\AppData\Local\Temp\ipykernel_28552\2388618874.py:56: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=top_winter_sports, x='Medal Count', y='Sport', ax=axes[1], palette='winter')

# %% [markdown]
# This code and visualization analyze participation and medal trends in the Summer and Winter Olympics across several dimensions:
#
# ### 1. **Participation Trends**:
# - The number of unique countries participating in each Olympic season over the years was calculated.
# - A **line plot** was created to compare participation trends for the Summer and Winter Olympics.
#   - **Insights**: The Summer Olympics consistently have higher participation, but both seasons show a growing trend in the number of participating countries over time.
#
# ### 2. **Top Medal-Winning Countries**:
# - Medal counts for each country were calculated and grouped by season.
# - The **top 10 medal-winning countries** for both the Summer and Winter Olympics were identified.
# - Two **bar charts** were created to visualize these rankings:
#   - The **left chart** shows the top-performing countries in the Summer Olympics.
#   - The **right chart** shows the top-performing countries in the Winter Olympics.
#   - **Insights**: These visualizations highlight which nations dominate in terms of medal achievements in both seasons.
#
# ### 3. **Top Medal-Winning Sports**:
# - Medal counts for each sport were calculated and grouped by season.
# - The **top 10 sports with the highest medal counts** for both the Summer and Winter Olympics were identified.
# - Two **bar charts** were generated:
#   - The **left chart** displays the top sports in the Summer Olympics.
#   - The **right chart** displays the top sports in the Winter Olympics.
#   - **Insights**: These plots reveal the most competitive sports in terms of medal distribution for both seasons.
#
# Overall, this analysis provides an in-depth look into Olympic participation and performance trends, offering valuable insights into how different countries and sports have performed across both Summer and Winter Olympic games.

# %% [markdown]
# **Conclusion:**
#
# The Olympics dataset offa of insi,ghts once cleaned and analysed. By resolving missing values and addressing historical nuances, we uncovered meaningful trends in participation, medal achievements, and gender representation. The analysis revealed that while the Summer Olympics consistently attract more participants, the Winter Olympics are closing the gender gap slightly faster. Dominant medal performances from certain nations and sports also stood out, with geopolitical shifts adding layers of complexity to the data. Overall, this study emphasizes the importance of thorough data cleaning and thoughtful analysis to tell a meaningful story about the world’s most celebrated sporting evnt.

# %% [markdown]
# **Team Members:**
# 1) Riya Shelwante 2502398
# 2) Vaishnavi Jadhav 2500370
# 3) Gabriel Rajan 2504957
# 4) Lemar Vega 2501567
